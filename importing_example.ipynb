# %%
# %matplotlib widget

import pandas as pd
import matplotlib.pyplot as plt

# %%
column_names = ['atom', 'x', 'y', 'z']
df = pd.read_csv('./reference_files/sI_5-10_6-2_cage.xyz',
                 sep='\s+',
                 names=column_names,
                 skiprows=2)
# the `sep='\s+` is necessary because I want to use whitespace
# as the separator and not just `sep=" "`

# %%
df
# Out:
#    atom         x         y         z
# 0     O  0.000000  0.000000  3.006068
# 1     O -0.000000 -0.000000 -3.006069
# 2     O  0.000000  2.320779  1.421994
# 3     O  0.000000  2.320779 -1.422006
# 4     O -0.000000 -2.320779  1.421994
# 5     O -0.000000 -2.320779 -1.422006
# 6     O  6.015000  3.006068  0.000000
# 7     O  6.015000 -3.006069  0.000000
# 8     O  6.015000  1.421994  2.320779
# 9     O  6.015000 -1.422006  2.320779
# 10    O  6.015000  1.421994 -2.320779
# 11    O  6.015000 -1.422006 -2.320779
# 12    O  3.694677  4.592849  0.000000
# 13    O  3.694677 -4.592849  0.000000
# 14    O  2.320322  0.000000  4.592849
# 15    O  2.320322 -0.000000 -4.592849
# 16    O  2.263372  3.712651  2.209694
# 17    O  2.263372  3.712651 -2.209695
# 18    O  2.263372 -3.712650  2.209694
# 19    O  2.263372 -3.712650 -2.209695
# 20    O  3.751628  2.209694  3.712651
# 21    O  3.751628 -2.209695  3.712651
# 22    O  3.751628  2.209694 -3.712650
# 23    O  3.751628 -2.209695 -3.712650

# %%
fig = plt.figure()
ax = fig.add_subplot(projection='3d')

ax.scatter(df['x'], df['y'], df['z'])
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
